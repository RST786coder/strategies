# %%
import yfinance as yf
import pandas as pd
from openpyxl import load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl import Workbook
import os

# %%
def get_last_trading_day(df):
    # Ensure 'Timestamp' is in datetime format
    df['Timestamp'] = pd.to_datetime(df['Timestamp'])
    # Get the last trading day
    last_day = df['Timestamp'].max()
    # Adjust for weekends (Saturday=5, Sunday=6)
    while last_day.weekday() >= 5:  # Saturday or Sunday
        last_day -= pd.Timedelta(days=1)
    return last_day

# %%
def trade_simulation(num_days, minute_file, fifteen_minute_file):
    all_results = []
    monthly_results = {}

    try:
        Odata_15m = pd.read_excel(fifteen_minute_file, index_col=None).drop(columns=['Unnamed: 0'], errors='ignore')
        Odata_1m = pd.read_excel(minute_file, index_col=None).drop(columns=['Unnamed: 0'], errors='ignore')
    except Exception as e:
        print(f"Error loading data: {e}")
        return
    

    end_date = get_last_trading_day(Odata_15m)
    start_date = end_date - pd.Timedelta(days=num_days + 14)
    
    Odata_15m['Timestamp'] = pd.to_datetime(Odata_15m['Timestamp'])
    Odata_1m['Timestamp'] = pd.to_datetime(Odata_1m['Timestamp'])

    trading_days = [end_date - pd.Timedelta(days=i) for i in range(num_days)]

    for trading_day in trading_days:
        trading_day_str = trading_day.strftime('%Y-%m-%d')
        prev_14_days_end = trading_day - pd.Timedelta(days=1)
        prev_14_days_start = prev_14_days_end - pd.Timedelta(days=14)
        next_trading_day = trading_day + pd.Timedelta(days=1)
        next_trading_day_str = next_trading_day.strftime('%Y-%m-%d')

        try:
            data_15m = Odata_15m[(Odata_15m['Timestamp'] >= prev_14_days_start) & (Odata_15m['Timestamp'] <= prev_14_days_end)]
            data_1m = Odata_1m[(Odata_1m['Timestamp'] >= trading_day_str) & (Odata_1m['Timestamp'] < next_trading_day_str)]

            if data_15m.empty or data_1m.empty:
                continue

            supports = data_15m[data_15m.Low == data_15m.Low.rolling(5, center=True).min()]['Low']
            resistances = data_15m[data_15m.High == data_15m.High.rolling(5, center=True).max()]['High']

            supports = supports.reindex(data_15m.index)
            resistances = resistances.reindex(data_15m.index)

            def near_divisible_by_500(level):
                return abs(level % 100) <= 15 or abs(level % 100 - 100) <= 15

            def count_touches(level, data):
                return ((level >= data['Open']) & (level <= data['Close'])).sum()

            filtered_supports = supports[
                (supports < data_15m['Open']) & (supports < data_15m['Close']) & supports.apply(near_divisible_by_500)
            ]
            filtered_resistances = resistances[
                (resistances > data_15m['Open']) & (resistances > data_15m['Close']) & resistances.apply(near_divisible_by_500)
            ]

            filtered_supports = filtered_supports[filtered_supports.apply(lambda x: 2 < count_touches(x, data_15m) <= 5)]
            filtered_resistances = filtered_resistances[filtered_resistances.apply(lambda x: 2 < count_touches(x, data_15m) <= 5)]

            levels = pd.concat([filtered_supports, filtered_resistances]).sort_index()

            trade_results = []
            trade_executed = False

            # Get the closing price at 3:15 PM
            closing_price = data_1m[data_1m['Timestamp'].dt.time == pd.to_datetime('15:15:00').time()]['Close'].iloc[-1] if not data_1m[data_1m['Timestamp'].dt.time == pd.to_datetime('15:15:00').time()].empty else None

            for i, row in data_1m.iterrows():
                if trade_executed:
                    break
                for level in levels:
                    if row['Low'] <= level <= row['High']:
                        open_price = row['Open']
                        trade_type, stoploss, target = ('Buy', level - 100, level + 210) if open_price > level else ('Sell', level + 100, level - 210)
                        
                        hit_target = hit_stoploss = False
                        entry_candle = row['Timestamp']
                        exit_candle = None
                        for j, next_row in data_1m.loc[i:].iterrows():
                            if trade_type == 'Buy':
                                if next_row['Low'] <= stoploss:
                                    hit_stoploss = True
                                    exit_candle = next_row['Timestamp']
                                    break
                                if next_row['High'] >= target:
                                    hit_target = True
                                    exit_candle = next_row['Timestamp']
                                    break
                            else:
                                if next_row['High'] >= stoploss:
                                    hit_stoploss = True
                                    exit_candle = next_row['Timestamp']
                                    break
                                if next_row['Low'] <= target:
                                    hit_target = True
                                    exit_candle = next_row['Timestamp']
                                    break

                        points = (target - level) if trade_type == 'Buy' and hit_target else (stoploss - level) if trade_type == 'Buy' and hit_stoploss else (level - target) if trade_type == 'Sell' and hit_target else (level - stoploss) if trade_type == 'Sell' and hit_stoploss else 0
                        
                        result = {
                            'Trading Day': trading_day_str,
                            'Entry Candle': entry_candle,
                            'Exit Candle': exit_candle,
                            'Level': level,
                            'Trade Type': trade_type,
                            'Stoploss': stoploss,
                            'Target': target,
                            'Hit Target': hit_target,
                            'Hit Stoploss': hit_stoploss,
                            'Result': 'Loss' if hit_stoploss else ('Win' if hit_target else 'Loss'),
                            'Points': points,
                            'Closing Price at 3:15 PM': closing_price
                        }
                        trade_results.append(result)
                        trade_executed = True
                        break  # Stop checking further levels once a trade is executed

            all_results.extend(trade_results)

                        # Collect monthly results
            for result in trade_results:
                month = pd.to_datetime(result['Trading Day']).strftime('%Y-%m')
                if month not in monthly_results:
                    monthly_results[month] = []
                monthly_results[month].append(result)

        except Exception as e:
            print(f"Error processing {trading_day_str}: {e}")
            continue

    file_path = 'results.xlsx'
    try:
        if os.path.exists(file_path):
            workbook = load_workbook(file_path)
            sheet = workbook.get_sheet_by_name('Results') if 'Results' in workbook.sheetnames else workbook.create_sheet(title='Results')
        else:
            workbook = Workbook()
            sheet = workbook.active
            sheet.title = 'Results'

        df_all_results = pd.DataFrame(all_results)
        total_wins = df_all_results['Result'].value_counts().get('Win', 0)
        total_losses = df_all_results['Result'].value_counts().get('Loss', 0)
        total_gain_points = df_all_results[df_all_results['Result'] == 'Win']['Points'].sum()
        total_loss_points = df_all_results[df_all_results['Result'] == 'Loss']['Points'].sum()
        net_total_points = total_gain_points + total_loss_points

        df_all_results['Entry Candle'] = df_all_results['Entry Candle'].dt.tz_localize(None)
        df_all_results['Exit Candle'] = df_all_results['Exit Candle'].dt.tz_localize(None)

        for r_idx, row in enumerate(dataframe_to_rows(df_all_results, index=False, header=True), 1):
            for c_idx, value in enumerate(row, 1):
                sheet.cell(row=r_idx, column=c_idx, value=value)

        summary_stats = [
            ['Total Wins', total_wins],
            ['Total Losses', total_losses],
            ['Total Gain Points', total_gain_points],
            ['Total Loss Points', total_loss_points],
            ['Net Total Points', net_total_points]
        ]
        summary_start_row = r_idx + 2

        for i, (stat, value) in enumerate(summary_stats):
            sheet.cell(row=summary_start_row + i, column=1, value=stat)
            sheet.cell(row=summary_start_row + i, column=2, value=value)
        
                # Add monthly sheets
        for month, results in monthly_results.items():
            if month not in workbook.sheetnames:
                monthly_sheet = workbook.create_sheet(title=month)
            else:
                monthly_sheet = workbook[month]

            df_monthly_results = pd.DataFrame(results)
            for r_idx, row in enumerate(dataframe_to_rows(df_monthly_results, index=False, header=True), 1):
                for c_idx, value in enumerate(row, 1):
                    monthly_sheet.cell(row=r_idx, column=c_idx, value=value)
                    
            # Calculate monthly summary stats
            total_wins_month = df_monthly_results['Result'].value_counts().get('Win', 0)
            total_losses_month = df_monthly_results['Result'].value_counts().get('Loss', 0)
            total_gain_points_month = df_monthly_results[df_monthly_results['Result'] == 'Win']['Points'].sum()
            total_loss_points_month = df_monthly_results[df_monthly_results['Result'] == 'Loss']['Points'].sum()
            net_total_points_month = total_gain_points_month + total_loss_points_month

            monthly_summary_stats = [
                ['Total Wins', total_wins_month],
                ['Total Losses', total_losses_month],
                ['Total Gain Points', total_gain_points_month],
                ['Total Loss Points', total_loss_points_month],
                ['Net Total Points', net_total_points_month]
            ]
            monthly_summary_start_row = len(df_monthly_results) + 3

            for i, (stat, value) in enumerate(monthly_summary_stats):
                monthly_sheet.cell(row=monthly_summary_start_row + i, column=1, value=stat)
                monthly_sheet.cell(row=monthly_summary_start_row + i, column=2, value=value)

        workbook.save(file_path)

    except Exception as e:
        print(f"Error saving results to Excel: {e}")

    return all_results

trade_simulation(num_days=180, minute_file='1_min.xlsx', fifteen_minute_file='15_min.xlsx')
# Out:
# [{'Trading Day': '2024-08-23',
#   'Entry Candle': Timestamp('2024-08-23 09:15:00'),
#   'Exit Candle': None,
#   'Level': 50910.9,
#   'Trade Type': 'Buy',
#   'Stoploss': 50810.9,
#   'Target': 51120.9,
#   'Hit Target': False,
#   'Hit Stoploss': False,
#   'Result': 'Loss',
#   'Points': 0,
#   'Closing Price at 3:15 PM': 50920.15},
#  {'Trading Day': '2024-08-22',
#   'Entry Candle': Timestamp('2024-08-22 09:15:00'),
#   'Exit Candle': Timestamp('2024-08-22 09:37:00'),
#   'Level': 50908.65,
#   'Trade Type': 'Sell',
#   'Stoploss': 51008.65,
#   'Target': 50698.65,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 51001.0},
#  {'Trading Day': '2024-08-21',
#   'Entry Candle': Timestamp('2024-08-21 09:15:00'),
#   'Exit Candle': Timestamp('2024-08-21 09:32:00'),
#   'Level': 50707.75,
#   'Trade Type': 'Sell',
#   'Stoploss': 50807.75,
#   'Target': 50497.75,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 50673.5},
#  {'Trading Day': '2024-08-20',
#   'Entry Candle': Timestamp('2024-08-20 09:38:00'),
#   'Exit Candle': Timestamp('2024-08-20 09:57:00'),
#   'Level': 50603.4,
#   'Trade Type': 'Sell',
#   'Stoploss': 50703.4,
#   'Target': 50393.4,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 50784.55},
#  {'Trading Day': '2024-08-19',
#   'Entry Candle': Timestamp('2024-08-19 09:16:00'),
#   'Exit Candle': Timestamp('2024-08-19 09:53:00'),
#   'Level': 50688.8,
#   'Trade Type': 'Sell',
#   'Stoploss': 50788.8,
#   'Target': 50478.8,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 50372.3},
#  {'Trading Day': '2024-08-16',
#   'Entry Candle': Timestamp('2024-08-16 09:25:00'),
#   'Exit Candle': Timestamp('2024-08-16 09:37:00'),
#   'Level': 50287.65,
#   'Trade Type': 'Sell',
#   'Stoploss': 50387.65,
#   'Target': 50077.65,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 50516.25},
#  {'Trading Day': '2024-08-08',
#   'Entry Candle': Timestamp('2024-08-08 09:15:00'),
#   'Exit Candle': Timestamp('2024-08-08 10:07:00'),
#   'Level': 50098.65,
#   'Trade Type': 'Sell',
#   'Stoploss': 50198.65,
#   'Target': 49888.65,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 50153.5},
#  {'Trading Day': '2024-08-02',
#   'Entry Candle': Timestamp('2024-08-02 09:15:00'),
#   'Exit Candle': Timestamp('2024-08-02 09:25:00'),
#   'Level': 51186.95,
#   'Trade Type': 'Sell',
#   'Stoploss': 51286.95,
#   'Target': 50976.95,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 51325.4},
#  {'Trading Day': '2024-07-30',
#   'Entry Candle': Timestamp('2024-07-30 09:15:00'),
#   'Exit Candle': Timestamp('2024-07-30 09:18:00'),
#   'Level': 51398.6,
#   'Trade Type': 'Sell',
#   'Stoploss': 51498.6,
#   'Target': 51188.6,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 51449.9},
#  {'Trading Day': '2024-07-29',
#   'Entry Candle': Timestamp('2024-07-29 09:18:00'),
#   'Exit Candle': Timestamp('2024-07-29 09:38:00'),
#   'Level': 51801.1,
#   'Trade Type': 'Sell',
#   'Stoploss': 51901.1,
#   'Target': 51591.1,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 51316.75},
#  {'Trading Day': '2024-07-24',
#   'Entry Candle': Timestamp('2024-07-24 09:20:00'),
#   'Exit Candle': Timestamp('2024-07-24 09:35:00'),
#   'Level': 51801.1,
#   'Trade Type': 'Sell',
#   'Stoploss': 51901.1,
#   'Target': 51591.1,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 51286.3},
#  {'Trading Day': '2024-07-23',
#   'Entry Candle': Timestamp('2024-07-23 09:42:00'),
#   'Exit Candle': Timestamp('2024-07-23 11:02:00'),
#   'Level': 52185.7,
#   'Trade Type': 'Buy',
#   'Stoploss': 52085.7,
#   'Target': 52395.7,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 51736.3},
#  {'Trading Day': '2024-07-22',
#   'Entry Candle': Timestamp('2024-07-22 09:15:00'),
#   'Exit Candle': Timestamp('2024-07-22 09:15:00'),
#   'Level': 52185.7,
#   'Trade Type': 'Sell',
#   'Stoploss': 52285.7,
#   'Target': 51975.7,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 52305.0},
#  {'Trading Day': '2024-07-19',
#   'Entry Candle': Timestamp('2024-07-19 11:00:00'),
#   'Exit Candle': Timestamp('2024-07-19 11:32:00'),
#   'Level': 52185.7,
#   'Trade Type': 'Buy',
#   'Stoploss': 52085.7,
#   'Target': 52395.7,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 52264.0},
#  {'Trading Day': '2024-07-18',
#   'Entry Candle': Timestamp('2024-07-18 09:15:00'),
#   'Exit Candle': Timestamp('2024-07-18 09:41:00'),
#   'Level': 52187.75,
#   'Trade Type': 'Buy',
#   'Stoploss': 52087.75,
#   'Target': 52397.75,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 52637.8},
#  {'Trading Day': '2024-07-11',
#   'Entry Candle': Timestamp('2024-07-11 09:15:00'),
#   'Exit Candle': Timestamp('2024-07-11 09:24:00'),
#   'Level': 52290.05,
#   'Trade Type': 'Buy',
#   'Stoploss': 52190.05,
#   'Target': 52500.05,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 52277.15},
#  {'Trading Day': '2024-07-10',
#   'Entry Candle': Timestamp('2024-07-10 09:18:00'),
#   'Exit Candle': Timestamp('2024-07-10 09:19:00'),
#   'Level': 52290.05,
#   'Trade Type': 'Buy',
#   'Stoploss': 52190.05,
#   'Target': 52500.05,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 52191.6},
#  {'Trading Day': '2024-07-08',
#   'Entry Candle': Timestamp('2024-07-08 12:13:00'),
#   'Exit Candle': Timestamp('2024-07-08 13:54:00'),
#   'Level': 52290.05,
#   'Trade Type': 'Buy',
#   'Stoploss': 52190.05,
#   'Target': 52500.05,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 52413.9},
#  {'Trading Day': '2024-07-05',
#   'Entry Candle': Timestamp('2024-07-05 09:15:00'),
#   'Exit Candle': Timestamp('2024-07-05 09:15:00'),
#   'Level': 52800.9,
#   'Trade Type': 'Sell',
#   'Stoploss': 52900.9,
#   'Target': 52590.9,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 52657.65},
#  {'Trading Day': '2024-07-04',
#   'Entry Candle': Timestamp('2024-07-04 10:27:00'),
#   'Exit Candle': Timestamp('2024-07-04 10:37:00'),
#   'Level': 53008.65,
#   'Trade Type': 'Buy',
#   'Stoploss': 52908.65,
#   'Target': 53218.65,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 53098.55},
#  {'Trading Day': '2024-07-03',
#   'Entry Candle': Timestamp('2024-07-03 09:15:00'),
#   'Exit Candle': Timestamp('2024-07-03 09:15:00'),
#   'Level': 52487.95,
#   'Trade Type': 'Buy',
#   'Stoploss': 52387.95,
#   'Target': 52697.95,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 53100.65},
#  {'Trading Day': '2024-07-02',
#   'Entry Candle': Timestamp('2024-07-02 09:15:00'),
#   'Exit Candle': Timestamp('2024-07-02 09:20:00'),
#   'Level': 52800.9,
#   'Trade Type': 'Sell',
#   'Stoploss': 52900.9,
#   'Target': 52590.9,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 52147.3},
#  {'Trading Day': '2024-06-28',
#   'Entry Candle': Timestamp('2024-06-28 09:15:00'),
#   'Exit Candle': Timestamp('2024-06-28 09:41:00'),
#   'Level': 52800.9,
#   'Trade Type': 'Buy',
#   'Stoploss': 52700.9,
#   'Target': 53010.9,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 52249.75},
#  {'Trading Day': '2024-06-24',
#   'Entry Candle': Timestamp('2024-06-24 10:47:00'),
#   'Exit Candle': Timestamp('2024-06-24 11:07:00'),
#   'Level': 51504.7,
#   'Trade Type': 'Sell',
#   'Stoploss': 51604.7,
#   'Target': 51294.7,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 51729.2},
#  {'Trading Day': '2024-06-14',
#   'Entry Candle': Timestamp('2024-06-14 09:15:00'),
#   'Exit Candle': Timestamp('2024-06-14 09:21:00'),
#   'Level': 50005.2,
#   'Trade Type': 'Sell',
#   'Stoploss': 50105.2,
#   'Target': 49795.2,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 50022.15},
#  {'Trading Day': '2024-06-13',
#   'Entry Candle': Timestamp('2024-06-13 09:15:00'),
#   'Exit Candle': Timestamp('2024-06-13 09:41:00'),
#   'Level': 50092.65,
#   'Trade Type': 'Buy',
#   'Stoploss': 49992.65,
#   'Target': 50302.65,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 49838.25},
#  {'Trading Day': '2024-06-12',
#   'Entry Candle': Timestamp('2024-06-12 09:50:00'),
#   'Exit Candle': Timestamp('2024-06-12 09:57:00'),
#   'Level': 49909.2,
#   'Trade Type': 'Sell',
#   'Stoploss': 50009.2,
#   'Target': 49699.2,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 49921.2},
#  {'Trading Day': '2024-06-11',
#   'Entry Candle': Timestamp('2024-06-11 10:35:00'),
#   'Exit Candle': Timestamp('2024-06-11 15:05:00'),
#   'Level': 49909.2,
#   'Trade Type': 'Sell',
#   'Stoploss': 50009.2,
#   'Target': 49699.2,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 49678.65},
#  {'Trading Day': '2024-06-07',
#   'Entry Candle': Timestamp('2024-06-07 09:15:00'),
#   'Exit Candle': Timestamp('2024-06-07 09:15:00'),
#   'Level': 49388.0,
#   'Trade Type': 'Sell',
#   'Stoploss': 49488.0,
#   'Target': 49178.0,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 49768.75},
#  {'Trading Day': '2024-06-06',
#   'Entry Candle': Timestamp('2024-06-06 09:15:00'),
#   'Exit Candle': Timestamp('2024-06-06 09:15:00'),
#   'Level': 49108.35,
#   'Trade Type': 'Buy',
#   'Stoploss': 49008.35,
#   'Target': 49318.35,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 49326.6},
#  {'Trading Day': '2024-06-05',
#   'Entry Candle': Timestamp('2024-06-05 11:14:00'),
#   'Exit Candle': Timestamp('2024-06-05 11:17:00'),
#   'Level': 47803.55,
#   'Trade Type': 'Sell',
#   'Stoploss': 47903.55,
#   'Target': 47593.55,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 49081.9},
#  {'Trading Day': '2024-06-04',
#   'Entry Candle': Timestamp('2024-06-04 09:29:00'),
#   'Exit Candle': Timestamp('2024-06-04 09:29:00'),
#   'Level': 49296.25,
#   'Trade Type': 'Buy',
#   'Stoploss': 49196.25,
#   'Target': 49506.25,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47045.6},
#  {'Trading Day': '2024-05-30',
#   'Entry Candle': Timestamp('2024-05-30 09:16:00'),
#   'Exit Candle': Timestamp('2024-05-30 09:18:00'),
#   'Level': 48601.75,
#   'Trade Type': 'Sell',
#   'Stoploss': 48701.75,
#   'Target': 48391.75,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 48680.35},
#  {'Trading Day': '2024-05-23',
#   'Entry Candle': Timestamp('2024-05-23 09:15:00'),
#   'Exit Candle': Timestamp('2024-05-23 09:43:00'),
#   'Level': 47892.25,
#   'Trade Type': 'Buy',
#   'Stoploss': 47792.25,
#   'Target': 48102.25,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 48777.85},
#  {'Trading Day': '2024-05-22',
#   'Entry Candle': Timestamp('2024-05-22 09:15:00'),
#   'Exit Candle': Timestamp('2024-05-22 09:20:00'),
#   'Level': 48003.9,
#   'Trade Type': 'Buy',
#   'Stoploss': 47903.9,
#   'Target': 48213.9,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47871.3},
#  {'Trading Day': '2024-05-21',
#   'Entry Candle': Timestamp('2024-05-21 09:15:00'),
#   'Exit Candle': Timestamp('2024-05-21 09:15:00'),
#   'Level': 48003.9,
#   'Trade Type': 'Sell',
#   'Stoploss': 48103.9,
#   'Target': 47793.9,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 48043.8},
#  {'Trading Day': '2024-05-16',
#   'Entry Candle': Timestamp('2024-05-16 10:38:00'),
#   'Exit Candle': Timestamp('2024-05-16 11:09:00'),
#   'Level': 47607.85,
#   'Trade Type': 'Buy',
#   'Stoploss': 47507.85,
#   'Target': 47817.85,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47982.3},
#  {'Trading Day': '2024-05-09',
#   'Entry Candle': Timestamp('2024-05-09 09:15:00'),
#   'Exit Candle': Timestamp('2024-05-09 09:15:00'),
#   'Level': 48213.75,
#   'Trade Type': 'Sell',
#   'Stoploss': 48313.75,
#   'Target': 48003.75,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 47463.7},
#  {'Trading Day': '2024-05-07',
#   'Entry Candle': Timestamp('2024-05-07 09:15:00'),
#   'Exit Candle': Timestamp('2024-05-07 09:32:00'),
#   'Level': 49014.85,
#   'Trade Type': 'Sell',
#   'Stoploss': 49114.85,
#   'Target': 48804.85,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 48301.45},
#  {'Trading Day': '2024-05-06',
#   'Entry Candle': Timestamp('2024-05-06 09:42:00'),
#   'Exit Candle': Timestamp('2024-05-06 09:54:00'),
#   'Level': 48902.7,
#   'Trade Type': 'Buy',
#   'Stoploss': 48802.7,
#   'Target': 49112.7,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 48903.1},
#  {'Trading Day': '2024-05-03',
#   'Entry Candle': Timestamp('2024-05-03 09:15:00'),
#   'Exit Candle': Timestamp('2024-05-03 09:15:00'),
#   'Level': 49399.3,
#   'Trade Type': 'Sell',
#   'Stoploss': 49499.3,
#   'Target': 49189.3,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 48960.6},
#  {'Trading Day': '2024-04-26',
#   'Entry Candle': Timestamp('2024-04-26 15:12:00'),
#   'Exit Candle': Timestamp('2024-04-26 15:25:00'),
#   'Level': 48088.85,
#   'Trade Type': 'Buy',
#   'Stoploss': 47988.85,
#   'Target': 48298.85,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 48197.4},
#  {'Trading Day': '2024-04-25',
#   'Entry Candle': Timestamp('2024-04-25 09:15:00'),
#   'Exit Candle': Timestamp('2024-04-25 09:15:00'),
#   'Level': 48009.55,
#   'Trade Type': 'Sell',
#   'Stoploss': 48109.55,
#   'Target': 47799.55,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 48480.95},
#  {'Trading Day': '2024-04-19',
#   'Entry Candle': Timestamp('2024-04-19 14:08:00'),
#   'Exit Candle': Timestamp('2024-04-19 14:44:00'),
#   'Level': 47609.8,
#   'Trade Type': 'Sell',
#   'Stoploss': 47709.8,
#   'Target': 47399.8,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 47621.2},
#  {'Trading Day': '2024-04-16',
#   'Entry Candle': Timestamp('2024-04-16 09:15:00'),
#   'Exit Candle': Timestamp('2024-04-16 15:29:00'),
#   'Level': 47501.7,
#   'Trade Type': 'Sell',
#   'Stoploss': 47601.7,
#   'Target': 47291.7,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47528.85},
#  {'Trading Day': '2024-04-12',
#   'Entry Candle': Timestamp('2024-04-12 12:41:00'),
#   'Exit Candle': Timestamp('2024-04-12 15:29:00'),
#   'Level': 48595.15,
#   'Trade Type': 'Buy',
#   'Stoploss': 48495.15,
#   'Target': 48805.15,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 48572.0},
#  {'Trading Day': '2024-04-09',
#   'Entry Candle': Timestamp('2024-04-09 14:12:00'),
#   'Exit Candle': None,
#   'Level': 48595.15,
#   'Trade Type': 'Buy',
#   'Stoploss': 48495.15,
#   'Target': 48805.15,
#   'Hit Target': False,
#   'Hit Stoploss': False,
#   'Result': 'Loss',
#   'Points': 0,
#   'Closing Price at 3:15 PM': 48746.5},
#  {'Trading Day': '2024-04-03',
#   'Entry Candle': Timestamp('2024-04-03 10:13:00'),
#   'Exit Candle': Timestamp('2024-04-03 12:12:00'),
#   'Level': 47501.7,
#   'Trade Type': 'Sell',
#   'Stoploss': 47601.7,
#   'Target': 47291.7,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47641.45},
#  {'Trading Day': '2024-04-02',
#   'Entry Candle': Timestamp('2024-04-02 09:15:00'),
#   'Exit Candle': Timestamp('2024-04-02 09:44:00'),
#   'Level': 47485.05,
#   'Trade Type': 'Buy',
#   'Stoploss': 47385.05,
#   'Target': 47695.05,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 47551.6},
#  {'Trading Day': '2024-03-28',
#   'Entry Candle': Timestamp('2024-03-28 09:15:00'),
#   'Exit Candle': Timestamp('2024-03-28 09:20:00'),
#   'Level': 46901.75,
#   'Trade Type': 'Sell',
#   'Stoploss': 47001.75,
#   'Target': 46691.75,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47035.4},
#  {'Trading Day': '2024-03-27',
#   'Entry Candle': Timestamp('2024-03-27 10:05:00'),
#   'Exit Candle': Timestamp('2024-03-27 14:56:00'),
#   'Level': 46901.75,
#   'Trade Type': 'Sell',
#   'Stoploss': 47001.75,
#   'Target': 46691.75,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 46830.75},
#  {'Trading Day': '2024-03-22',
#   'Entry Candle': Timestamp('2024-03-22 09:15:00'),
#   'Exit Candle': Timestamp('2024-03-22 09:36:00'),
#   'Level': 46688.35,
#   'Trade Type': 'Sell',
#   'Stoploss': 46788.35,
#   'Target': 46478.35,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 46845.3},
#  {'Trading Day': '2024-03-21',
#   'Entry Candle': Timestamp('2024-03-21 09:15:00'),
#   'Exit Candle': Timestamp('2024-03-21 09:20:00'),
#   'Level': 46711.7,
#   'Trade Type': 'Sell',
#   'Stoploss': 46811.7,
#   'Target': 46501.7,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 46712.4},
#  {'Trading Day': '2024-03-19',
#   'Entry Candle': Timestamp('2024-03-19 09:15:00'),
#   'Exit Candle': Timestamp('2024-03-19 09:26:00'),
#   'Level': 46489.45,
#   'Trade Type': 'Sell',
#   'Stoploss': 46589.45,
#   'Target': 46279.45,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 46368.6},
#  {'Trading Day': '2024-03-18',
#   'Entry Candle': Timestamp('2024-03-18 12:25:00'),
#   'Exit Candle': Timestamp('2024-03-18 15:08:00'),
#   'Level': 46711.7,
#   'Trade Type': 'Sell',
#   'Stoploss': 46811.7,
#   'Target': 46501.7,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 46606.3},
#  {'Trading Day': '2024-03-12',
#   'Entry Candle': Timestamp('2024-03-12 09:15:00'),
#   'Exit Candle': Timestamp('2024-03-12 09:34:00'),
#   'Level': 47294.75,
#   'Trade Type': 'Buy',
#   'Stoploss': 47194.75,
#   'Target': 47504.75,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 47265.4},
#  {'Trading Day': '2024-03-07',
#   'Entry Candle': Timestamp('2024-03-07 09:15:00'),
#   'Exit Candle': Timestamp('2024-03-07 09:29:00'),
#   'Level': 48012.15,
#   'Trade Type': 'Buy',
#   'Stoploss': 47912.15,
#   'Target': 48222.15,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47854.2},
#  {'Trading Day': '2024-03-01',
#   'Entry Candle': Timestamp('2024-03-01 09:15:00'),
#   'Exit Candle': Timestamp('2024-03-01 09:15:00'),
#   'Level': 46398.1,
#   'Trade Type': 'Sell',
#   'Stoploss': 46498.1,
#   'Target': 46188.1,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 47330.1},
#  {'Trading Day': '2024-02-28',
#   'Entry Candle': Timestamp('2024-02-28 10:08:00'),
#   'Exit Candle': Timestamp('2024-02-28 10:51:00'),
#   'Level': 46692.25,
#   'Trade Type': 'Sell',
#   'Stoploss': 46792.25,
#   'Target': 46482.25,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 45935.85},
#  {'Trading Day': '2024-02-27',
#   'Entry Candle': Timestamp('2024-02-27 09:15:00'),
#   'Exit Candle': Timestamp('2024-02-27 12:59:00'),
#   'Level': 46513.55,
#   'Trade Type': 'Sell',
#   'Stoploss': 46613.55,
#   'Target': 46303.55,
#   'Hit Target': False,
#   'Hit Stoploss': True,
#   'Result': 'Loss',
#   'Points': -100.0,
#   'Closing Price at 3:15 PM': 46584.05},
#  {'Trading Day': '2024-02-26',
#   'Entry Candle': Timestamp('2024-02-26 09:26:00'),
#   'Exit Candle': Timestamp('2024-02-26 09:58:00'),
#   'Level': 46806.15,
#   'Trade Type': 'Sell',
#   'Stoploss': 46906.15,
#   'Target': 46596.15,
#   'Hit Target': True,
#   'Hit Stoploss': False,
#   'Result': 'Win',
#   'Points': 210.0,
#   'Closing Price at 3:15 PM': 46578.75}]
